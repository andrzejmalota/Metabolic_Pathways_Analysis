# %%
from os.path import join
data_dir = '../metabolic_pathways'

# %%
import networkx as nx
g = nx.read_edgelist(join(data_dir, 'out.maayan-figeys'), create_using=nx.DiGraph(), nodetype = int)
nx.draw(g)
